# %% [markdown]
# # Table of Contents
#
# * [Import Libraries](#Impoert_libraries)
# * [Exploratory data analysis(EDA)](#EDA)
# * [Dash Board plotly code](#dash_board)

# %% [markdown]
# ## Import Libraries <a class="anchor" id="Impoert_libraries"></a>

# %%
import pandas as pd
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px

df = pd.read_csv('Proactive Data.csv')
# Out:
# C:\Users\AHMEDH~1\AppData\Local\Temp/ipykernel_8392/3743111519.py:3: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\AHMEDH~1\AppData\Local\Temp/ipykernel_8392/3743111519.py:4: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %% [markdown]
# ## Exploratory data analysis (EDA) <a class="anchor" id="EDA"></a>

# %%
df.head()
# Out:
#                 Division Observation.related.to Type.of.Activity  \
# 0          Raw Materials               Employee           Others
# 1          Raw Materials               Employee           Others
# 2  Engineering & Project               Employee       Operations
# 3  Engineering & Project             Contractor      Maintenance
# 4  Engineering & Project             Contractor       Operations
#
#   Observation.Category    Reason.for.Deviation   Day      Month  \
# 0     Workplace Safety  Procedure Not Followed  Tue       April
# 1          Orderliness  Procedure Not Followed   Wed      April
# 2              Falling  Procedure Not Followed   Thu     August
# 3    Electrical Safety  Procedure Not Followed   Fri     August
# 4             Handrail  Procedure Not Followed   Sat  September
#
#            Primary.Cause Working.Condition Machine.Condition  \
# 0      Material Handling    Not Applicable    Not Applicable
# 1          Road Incident    Not Applicable    Not Applicable
# 2      Dashing/Collision     Group Working       M/C Working
# 3  Lifting Tools Tackles    Single Working          M/C Idle
# 4             Hot Metals    Single Working       M/C Working
#
#                 Observation.Type   Safety.Standards Incident.Type  \
# 0  Unsafe Act & Unsafe Condition             Others     Behaviour
# 1  Unsafe Act & Unsafe Condition             Others     Behaviour
# 2                     Unsafe Act  Tools & Equipment       Process
# 3            Unsafe Act by Other        Road Safety     Behaviour
# 4                     Unsafe Act                PPE       Process
#
#   SOP.Combined    Topic Injury_risk     Injury Type
# 0         SNNR  Topic 1        High  Serious Injury
# 1         SNNR  Topic 1        High  Serious Injury
# 2          SNR  Topic 4      Medium             IOW
# 3         SNNR  Topic 5        High           Fatal
# 4          SAF  Topic 7         Low       First Aid

# %%
#git information about your data to check the needed data cleaning and featuer engineering process
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1897 entries, 0 to 1896
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Division                1897 non-null   object
#  1   Observation.related.to  1897 non-null   object
#  2   Type.of.Activity        1897 non-null   object
#  3   Observation.Category    1897 non-null   object
#  4   Reason.for.Deviation    1897 non-null   object
#  5   Day                     1897 non-null   object
#  6   Month                   1897 non-null   object
#  7   Primary.Cause           1897 non-null   object
#  8   Working.Condition       1897 non-null   object
#  9   Machine.Condition       1897 non-null   object
#  10  Observation.Type        1897 non-null   object
#  11  Safety.Standards        1897 non-null   object
#  12  Incident.Type           1897 non-null   object
#  13  SOP.Combined            1897 non-null   object
#  14  Topic                   1897 non-null   object
#  15  Injury_risk             1897 non-null   object
#  16  Injury Type             1897 non-null   object
# dtypes: object(17)
# memory usage: 252.1+ KB

# %%
# The Following step because there is a duplicated value of Tue
vc = df['Day'].value_counts()
u  = [i not in set(vc[vc==1].index) for i in df['Day']]
df = df[u]

for col in df.columns:
    print(f'For column {col}\n------------------\n')
    print(df[col].value_counts())
    print('\n')
# Out:
# For column Division
# ------------------
#
# Raw Materials             466
# Engineering & Project     378
# Shared Services           312
# Steel Manufacturing       301
# Corporate Services        283
# Others                     81
#  TQM & Steel Business      50
# Orissa Projects            14
# Bearing Division           11
# Name: Division, dtype: int64
#
#
# For column Observation.related.to
# ------------------
#
# Employee      1412
# Contractor     484
# Name: Observation.related.to, dtype: int64
#
#
# For column Type.of.Activity
# ------------------
#
# Others                         958
# Operations                     414
# Maintenance                    333
# Construction                   115
# Transportation                  28
# Errection & Commissioning       21
# Loading & Unloading              7
# Loco Operation                   6
# Packing of finished product      5
# ...                              5
# Breaking & Sizing                4
# Name: Type.of.Activity, dtype: int64
#
#
# For column Observation.Category
# ------------------
#
# Not Maintained         211
# Others                 161
# Not Followed           150
# Orderliness            142
# Barricading            124
# Mines Safety           117
# Workplace Safety       100
# Road Safety             97
# PPE                     94
# Process Safety          88
# Uneasiness              84
# Electrical Safety       79
# Material Handling       65
# Falling                 62
# Health                  53
# Environment             38
# Tools & Equipment       37
# Gas Safety              37
# Eyes & Face             30
# Not Understood          26
# Handrail                22
# Fire Safety             20
# Caught Between          16
# Confine Space           16
# Excavation              16
# Temp. Elect. Wiring     11
# Name: Observation.Category, dtype: int64
#
#
# For column Reason.for.Deviation
# ------------------
#
# Procedure Not Followed    1360
# Procedure Not Adequate     314
# Procedure Not Existing     222
# Name: Reason.for.Deviation, dtype: int64
#
#
# For column Day
# ------------------
#
# Wed    330
# Fri    302
# Mon    294
# Thu    289
# Tue    272
# Sat    252
# Sun    157
# Name: Day, dtype: int64
#
#
# For column Month
# ------------------
#
# August       203
# June         191
# July         185
# April        181
# September    175
# December     174
# May          173
# November     163
# March        142
# October      140
# February     117
# January       52
# Name: Month, dtype: int64
#
#
# For column Primary.Cause
# ------------------
#
# Slip/Trip/Fall                522
# Road Incident                 342
# Material Handling             258
# Process Incidents             249
# Dashing/Collision             163
# Skidding                       67
# Lifting Tools Tackles          51
# Medical Ailment                38
# Hydraulic/Pneumatic            30
# Structural Integrity           24
# Workplace Safety               22
# Hot Metals                     20
# Electrical Flash               18
# Equipment Machinery Damage     17
# Run Over                       16
# Fire/Explosion                 11
# Gas Leakage                    11
# Toxic Chemicals                10
# Energy Isolation                9
# Occupational Illness            6
# Rail                            5
# Derailment                      5
# Crane Dashing                   2
# Name: Primary.Cause, dtype: int64
#
#
# For column Working.Condition
# ------------------
#
# Group Working     827
# Single Working    819
# Not Applicable    250
# Name: Working.Condition, dtype: int64
#
#
# For column Machine.Condition
# ------------------
#
# Not Applicable    749
# M/C Working       588
# M/C Idle          559
# Name: Machine.Condition, dtype: int64
#
#
# For column Observation.Type
# ------------------
#
# Unsafe Act                       997
# Unsafe Condition                 440
# Unsafe Act by Other              241
# Unsafe Act & Unsafe Condition    218
# Name: Observation.Type, dtype: int64
#
#
# For column Safety.Standards
# ------------------
#
# Orderliness              292
# Road Safety              215
# Others                   201
# Workplace Safety         157
# Tools & Equipment        144
# Material Handling        131
# PPE                      124
# Excavation               119
# Fire Safety              100
# Mines Safety              77
# Process Safety            72
# Barricading               66
# Electrical Safety         55
# Others,Process Safety     55
# Gas Cutting & Welding     52
# Confine Space             36
# Name: Safety.Standards, dtype: int64
#
#
# For column Incident.Type
# ------------------
#
# Behaviour    1542
# Process       354
# Name: Incident.Type, dtype: int64
#
#
# For column SOP.Combined
# ------------------
#
# SANF    729
# SNNR    368
# SIF     246
# SAF     206
# SINF    203
# SNR     144
# Name: SOP.Combined, dtype: int64
#
#
# For column Topic
# ------------------
#
# Topic 3    426
# Topic 7    225
# Topic 1    208
# Topic 2    206
# Topic 8    190
# Topic 4    185
# Topic 9    175
# Topic 6    173
# Topic 5    108
# Name: Topic, dtype: int64
#
#
# For column Injury_risk
# ------------------
#
# Low       1371
# High       264
# Medium     261
# Name: Injury_risk, dtype: int64
#
#
# For column Injury Type
# ------------------
#
# First Aid               1099
# Normal                   227
# Exgratia                 226
# IOW                      186
# Serious Injury            39
# Restricted Work Case      36
# Claim IOW                 32
# Fatal                     17
# Foreign Body              15
# Serious                   12
# Claim IOD                  4
# Death                      2
# First Aid Case             1
# Name: Injury Type, dtype: int64

# %%
#show the frequances of accident primary causes
px.histogram(df, x="Primary.Cause")
# Out:
# <div>                            <div id="b847d87b-139a-4f1a-aff8-1b5e2be9cde7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b847d87b-139a-4f1a-aff8-1b5e2be9cde7")) {                    Plotly.newPlot(                        "b847d87b-139a-4f1a-aff8-1b5e2be9cde7",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Primary.Cause=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["Material Handling","Road Incident","Dashing/Collision","Lifting Tools Tackles","Hot Metals","Process Incidents","Process Incidents","Road Incident","Slip/Trip/Fall","Slip/Trip/Fall","Slip/Trip/Fall","Material Handling","Road Incident","Road Incident","Slip/Trip/Fall","Slip/Trip/Fall","Slip/Trip/Fall","Process Incidents","Skidding","Workplace Safety","Slip/Trip/Fall","Slip/Trip/Fall","Road Incident","Skidding","Skidding","Road Incident","Process Incidents","Road Incident","Road Incident","Material Handling","Material Handling","Slip/Trip/Fall","Slip/Trip/Fall","Slip/Trip/Fall","Process Incidents","Process Incidents","Material Handling","Dashing/Collision","Dashing/Collision","Dashing/Collision","Material Handling","Slip/Trip/Fall","Slip/Trip/Fall","Fire/Explosion","Process Incidents","Process Incidents","Material Handling","Material Handling","Material Handling","Process Incidents","Process Incidents","Road Incident","Slip/Trip/Fall","Slip/Trip/Fall","Slip/Trip/Fall","Slip/Trip/Fall","Slip/Trip/Fall","Road Incident","Energy Isolation","Energy Isolation","Road Incident","Material Handling","Road Incident","Skidding","Skidding","Skidding","Skidding","Slip/Trip/Fall","Dashing/Collision","Electrical Flash","Dashing/Collision","Road Incident","Road Incident","Hydraulic/Pneumatic","Road Incident","Electrical Flash","Slip/Trip/Fall","Road Incident","Material Handling","Hot Metals","Road Incident","Skidding","Dashing/Collision","Road Incident","Slip/Trip/Fall","Slip/Trip/Fall","Run Over","Run Over","Slip/Trip/Fall","Slip/Trip/Fall","Road Incident","Process Incidents","Process Incidents","Road Incident","Process Incidents","Process Incidents","Slip/Trip/Fall","Road Incident","Road Incident","Material Handling","Material Handling","Lifting Tools Tackles","Process Incidents","Dashing/Collision","Road Incident","Road Incident","Road Incident","Road Incident","Slip/Trip/Fall","Material Handling","Road Incident","Structural Integrity","Lifting Tools Tackles","Process Incidents","Slip/Trip/Fall","Slip/Trip/Fall","Slip/Trip/Fall","Workplace Safety","Workplace Safety","Material Handling","Road Incident","Dashing/Collision","Process Incidents","Process Incidents","Road Incident","Material Handling","Hot Metals","Skidding","Slip/Trip/Fall","Slip/Trip/Fall","Road Incident","Road Incident","Process Incidents","Road Incident","Slip/Trip/Fall","Dashing/Collision","Equipment Machinery Damage","Toxic Chemicals","Lifting Tools Tackles","Lifting Tools Tackles","Material Handling","Slip/Trip/Fall","Slip/Trip/Fall","Slip/Trip/Fall","Slip/Trip/Fall","Material Handling","Slip/Trip/Fall","Slip/Trip/Fall","Lifting Tools Tackles","Slip/Trip/Fall","Slip/Trip/Fall","Hot Metals","Road Incident","Slip/Trip/Fall","Slip/Trip/Fall","Dashing/Collision","Slip/Trip/Fall","Slip/Trip/Fall","Slip/Trip/Fall","Slip/Trip/Fall","Slip/Trip/Fall","Dashing/Collision","Slip/Trip/Fall","Slip/Trip/Fall","Road Incident","Slip/Trip/Fall","Dashing/Collision","Structural Integrity","Structural Integrity","Road Incident","Process Incidents","Material Handling","Road Incident","Slip/Trip/Fall","Material Handling","Slip/Trip/Fall","Road Incident","Process Incidents","Road Incident","Energy Isolation","Dashing/Collision","Road Inc ...

# %%
#visualize the risk level with division of work to see the frequancies of risk level in each division and in same time the
# most incident type responsable about it
df1 = df[["Division","Injury_risk"]].value_counts().reset_index(name='count').rename(columns={'index': 'Division'})
df_merge=pd.merge(df,df1,on=['Division','Injury_risk'], how='left' )
px.scatter(df_merge, x="Division", y="Injury_risk",size='count',color='Incident.Type',
                  size_max=50)
# Out:
# <div>                            <div id="858b96f9-04a0-4c30-8bea-c2d99571edf2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("858b96f9-04a0-4c30-8bea-c2d99571edf2")) {                    Plotly.newPlot(                        "858b96f9-04a0-4c30-8bea-c2d99571edf2",                        [{"hovertemplate":"Incident.Type=Behaviour<br>Division=%{x}<br>Injury_risk=%{y}<br>count=%{marker.size}<extra></extra>","legendgroup":"Behaviour","marker":{"color":"#636efa","size":[58,58,80,228,228,228,212,212,5,5,18,351,351,351,351,229,58,58,351,351,70,70,70,27,351,351,45,351,351,58,58,45,351,351,40,351,351,351,351,351,351,212,45,212,229,229,60,40,60,212,212,229,351,351,58,58,228,60,351,351,45,212,228,212,58,60,228,228,45,228,18,262,351,351,27,70,70,262,229,262,80,80,212,351,351,262,58,58,228,229,228,228,351,351,262,212,27,229,229,229,262,262,212,229,212,262,262,262,262,229,262,262,351,351,229,16,229,262,45,18,212,70,228,40,70,228,228,80,60,18,80,45,40,212,18,212,212,212,45,80,229,212,228,228,70,228,228,212,351,351,351,351,212,351,351,45,60,212,212,27,33,212,262,351,351,351,351,60,262,228,212,40,351,351,212,16,262,262,58,58,351,351,9,212,58,262,212,262,212,212,228,262,262,262,262,229,262,262,262,351,351,229,262,212,228,60,16,45,262,262,229,262,8,228,351,351,262,262,228,33,228,45,7,229,80,33,33,229,229,262,70,229,262,27,229,262,262,18,262,262,262,80,9,262,262,262,262,33,33,262,229,262,262,262,228,33,228,33,3,45,27,229,16,262,45,228,18,351,351,229,229,45,45,58,58,18,228,229,229,351,351,5,45,18,262,5,229,58,229,18,212,27,18,27,229,229,262,229,18,262,351,351,45,18,351,351,45,70,45,45,18,212,18,45,351,351,45,60,229,18,18,45,27,228,18,45,58,58,45,351,351,70,351,351,351,351,229,351,351,212,351,351,80,58,351,351,351,351,5,45,262,27,229,229,228,229,229,80,58,58,45,351,351,228,228,33,351,351,229,212,70,212,60,212,5,212,18,45,45,228,228,228,228,228,5,228,58,58,70,228,228,80,228,228,351,351,351,351,229,351,351,229,212,58,58,58,212,351,58,80,58,228,228,212,212,212,228,80,228,212,60,212,212,228,212,212,228,212,16,229,212,212,212,229,212,18,228,212,212,18,70,212,212,212,40,58,228,228,351,228,70,212,70,228,212,58,212,60,80,70,229,212,80,351,351,212,351,351,60,351,351,351,351,351,45,228,228,351,351,351,351,228,70,351,351,262,70,262,80,70,80,351,351,228,58,58,351,351,262,351,351,228,228,229,212,351,262,229,58,58,212,351,351,58,212,228,351,351,351,351,228,228,351,351,58,351,351,351,351,351,351,351,58,351,228,70,351,80,351,228,228,351,351,70,228,351,351,351,351,228,80,228,58,70,228,351,351,351,228,228,351,229,228,351,351,228,351,80,228,228,70,351,351,229,351,351,228,58,228,58,351,228,351,228,58,262,229,229,229,229,33,229,45,229,262,60,262,229,229,45,45,229,45,262,262,229,229,262,45,229,45,229,229,9,27,8,212,212,262,229,262,229,229,212,45,262,212,70,70,229,45,45,212,45,212,80,262,18,228,228,228,70,60,80,212,45,80,80,70,228,40,45,40,228,228,40,262,70,70,228,228,70,228,16,212,70,228,18,228,7,228,80,228,228,228,228,228,60,70,70,228,212,228,228,70,18,228,80,228,228,351,351,212,212,262,351,58,351,58,262,60,351,351,262,228,58,58,212,228,262,58,58,262,212,60,262,351,351,228,212,70,351,58,351,40,40,351,262,212,228,212,262,262,212,80,228,70,212,212,351,262,58,40,212,228,228,351,228,212,228,262,212,58,58,229,228,262,60,80,351,351,33,9,70,45,262,33,33,262,262,228,262,229,262,229,27,40,262,262,33,8,229,80,262,229,212,351,212,262,229,58,229,212,229,229,229,229,33,228,80,351,351,228,229,16,8,351,45,229,80,229,262,45,27,45,58,228,212,351,229,351,228,58,228,60,228,58,228,228,228,228,212,212,58,212,45,45,351,229,229,351,229,80,229,351,80,40,351,228,58,27,40,212,351,229,351,80,228,60,212,60,60,228,80,80,228,228,229,70,70,80,212,212,60,228,60,212,229,60,70,80,58,212,4,212,70,229,80,58,60,228,80,229,212,70,212,80,60,212,70,212,228,212,212,4,60,2 ...

# %% [markdown]
# ## Dash Board plotly code <a class="anchor" id="dash_board"></a>

# %% [markdown]
# **Here we will make dash board using plotly dash to visualize pervious plots with another interative plots to make EDA more Easy and flexable for ordinary users**

# %%
df = pd.read_csv('Proactive Data.csv')
procedure_count=df['Reason.for.Deviation'].value_counts()
proced_not_followed=procedure_count[0]
proced_not_adequete=procedure_count[1]
proced_not_exits=procedure_count[2]

app = dash.Dash(__name__)
#get the css ready styles from link in external style sheeet argument
app =dash.Dash(external_stylesheets=['https://codepen.io/chriddyp/pen/bWLwgP.css', 'assets/own_style.css'])

#build the dashbord from next html code
app.layout = html.Div([
    html.H1('Risk and accident in sites',style={'textAlign':'center','fontSize':30}),
    html.Div([html.H2('Number of times that procedures Not',style={'textAlign':'center','fontSize':25})],className='row'),
    
    html.Div([
               html.Div(['Followed:'],style={'textAlign':'right','fontSize':35},className='two columns'),
               html.Div([proced_not_followed],style={'textAlign':'left','fontSize':35},className='two columns'),
               html.Div(['Adequete:'],style={'textAlign':'right','fontSize':35},className='two columns'),
               html.Div([proced_not_adequete], style={'textAlign':'left','fontSize':35},className='two columns'),
               html.Div(['Exits:'],style={'textAlign':'right','fontSize':35},className='two columns'),
               html.Div([proced_not_exits], id='point',style={'textAlign':'left','fontSize':35},className='two columns'),
             ],style={'textAlign':'center','background-color': 'rgb(250, 124, 27,.7)'}, className='row'),
    
    html.Div([
            html.Div([dcc.Dropdown(
                id='obs-column',
                options=[{'label': i, 'value': i} for i in df['Observation.related.to'].unique()],value='Employee'
            )],className='six columns'),
            html.Div([dcc.Dropdown(
                id='type-column',
                options=[{'label': i, 'value': i} for i in df['Type.of.Activity'].unique()],value='Operations',
                    placeholder='choose a value...'
            )],className='six columns')],className='row'),
    
    
    html.Div([
        html.Div([dcc.Graph(id='primary_graph')],className='six columns'),
        html.Div([dcc.Graph(id='injure_graph')],className='six columns')
    ],className='row'),
    html.Div([dcc.Graph(id='ob_injure_graph')],className='row')
])


@app.callback(
    Output('primary_graph', 'figure'),
    Output('injure_graph', 'figure'),
    Output('ob_injure_graph', 'figure'),
    Input('obs-column', 'value'),
    Input('type-column', 'value'))


#the function responsable about the changes in visualizations according the entries getting from user
def update_figure(obs_selected,type_selected):
    
    filtered_df = df[(df['Observation.related.to'] == obs_selected)&(df['Type.of.Activity'] == type_selected)]

    fig = px.histogram(filtered_df, y="Primary.Cause")
    fig.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', xaxis_tickangle=-90,\
                  title={'text': 'Accident primary cause','y':0.96,'x':0.5, 'xanchor': 'center','yanchor': 'top'})
    
    fig1 = px.histogram(filtered_df, y="Injury Type")
    fig1.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', xaxis_tickangle=-90,\
                  title={'text': 'different Injure Types','y':0.96,'x':0.5, 'xanchor': 'center','yanchor': 'top'})
    
    df1 = df[["Division","Injury_risk"]].value_counts().reset_index(name='count').rename(columns={'index': 'Division'})
    df_merge=pd.merge(df,df1,on=['Division','Injury_risk'], how='left' )
    
    fig2 = px.scatter(df_merge, x="Division", y="Injury_risk",size='count',color='Incident.Type',size_max=40)
    fig2.update_layout(uniformtext_minsize=8, uniformtext_mode='hide', xaxis_tickangle=-90,\
                  title={'text': 'Injure risk size for every division','y':0.96,'x':0.5, 'xanchor': 'center','yanchor': 'top'})
    
    return fig,fig1,fig2

# if _name_ == '_main_':
app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [20/Feb/2022 14:58:04] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Feb/2022 14:58:04] "GET /assets/own_style.css HTTP/1.1" 404 -
# 127.0.0.1 - - [20/Feb/2022 14:58:04] "GET /_dash-component-suites/dash/deps/react@16.v2_2_0m1645360490.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Feb/2022 14:58:04] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_2_0m1645360490.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Feb/2022 14:58:04] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_2_0m1645360490.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Feb/2022 14:58:04] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_2_0m1645360490.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Feb/2022 14:58:04] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_2_0m1645360490.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Feb/2022 14:58:04] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_2_0m1645360490.js HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Feb/2022 14:58:04] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_2_0m1645360490.js HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Feb/2022 14:58:04] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_2m1645360491.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Feb/2022 14:58:04] "GET /_dash-component-suites/dash/dash_table/bundle.v5_1_1m1645360490.js HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Feb/2022 14:58:05] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Feb/2022 14:58:05] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Feb/2022 14:58:05] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Feb/2022 14:58:05] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Feb/2022 14:58:05] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Feb/2022 14:58:05] "GET /_favicon.ico?v=2.2.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Feb/2022 14:58:05] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Feb/2022 14:58:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Feb/2022 14:58:22] "POST /_dash-update-component HTTP/1.1" 200 -
